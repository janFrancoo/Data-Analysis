# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('../Data/wine_quality.csv')
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6487.000000       6489.000000  6494.000000     6495.000000
# mean        7.216579          0.339691     0.318722        5.444326
# std         1.296750          0.164649     0.145265        4.758125
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6495.000000          6497.000000           6497.000000  6497.000000
# mean      0.056042            30.525319            115.744574     0.994697
# std       0.035036            17.749400             56.521855     0.002999
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
# type                    6497 non-null object
# fixed acidity           6487 non-null float64
# volatile acidity        6489 non-null float64
# citric acid             6494 non-null float64
# residual sugar          6495 non-null float64
# chlorides               6495 non-null float64
# free sulfur dioxide     6497 non-null float64
# total sulfur dioxide    6497 non-null float64
# density                 6497 non-null float64
# pH                      6488 non-null float64
# sulphates               6493 non-null float64
# alcohol                 6497 non-null float64
# quality                 6497 non-null int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
df['alcohol'].mean()
# Out:
# 10.491800831149511

# %%
df.hist(column='alcohol', bins=15)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D03285C608>]],
#       dtype=object)

# %%
df.hist(column='alcohol', bins=15, grid=False, figsize=(10, 6), color='purple')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D032B1FBC8>]],
#       dtype=object)

# %%
sns.distplot(df['alcohol'], bins=25, kde=False)

# %%
sns.distplot(df['alcohol'], bins=15, kde=True, color='red')

# %%
df['alcohol'].value_counts()
# Out:
# 9.500000     367
# 9.400000     332
# 9.200000     271
# 10.000000    229
# 10.500000    227
#             ...
# 11.850000      1
# 14.050000      1
# 14.900000      1
# 12.066667      1
# 11.733333      1
# Name: alcohol, Length: 111, dtype: int64

# %%
_ = sns.distplot(df['alcohol'])
_ = plt.xlabel('Alcohol Percentage')
_ = plt.ylabel('Count')
_ = plt.title('Alcohol Content')
plt.show()

# %%
sns.set_style('dark')
sns.distplot(df['alcohol'])

# %%
sns.lmplot(x='alcohol', y='fixed acidity', data=df)

# %%
sns.lmplot(x='alcohol', y='density', data=df, fit_reg=False)

# %%
sns.lmplot(x='alcohol', y='chlorides', data=df, fit_reg=False, hue='type')

# %%
df['alcohol'].quantile(0.5)
# Out:
# 10.3

# %%
df['alcohol'].quantile([0.05, 0.95])
# Out:
# 0.05     9.0
# 0.95    12.7
# Name: alcohol, dtype: float64

# %%
print(df['alcohol'].quantile([0.25, 0.75]))
plt.figure(figsize=(10, 6))
sns.boxplot(data=df['alcohol'])
# Out:
# 0.25     9.5
# 0.75    11.3
# Name: alcohol, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='quality', data=df, hue='type')

# %%
sns.set_style('whitegrid')
df = sns.load_dataset('titanic')

sns.catplot(x='class', y='survived', hue='sex', data=df, height=6, kind='bar', palette='muted').set_ylabels('Survival prob')

# %%
df = pd.read_csv('../Data/wine_quality.csv')

# %%
sns.factorplot(x='free sulfur dioxide', y='alcohol', data=df, col='quality', kind='point')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
plt.plot(df['alcohol'].sort_values(), np.arange(1, len(df['alcohol'])+1) / len(df['alcohol']), marker='.', linestyle='none')
plt.grid(True)
plt.show()

# %%
corr = df.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(corr, cmap=sns.diverging_palette(220, 10, as_cmap=True))

# %%
sns.pairplot(df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
